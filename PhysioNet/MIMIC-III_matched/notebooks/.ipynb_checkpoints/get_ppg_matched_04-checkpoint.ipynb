# %%
import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import os.path
from bs4 import BeautifulSoup
import requests

# %%
first_record = 6000
last_record = 8000
record_segment_file_name = '../../../2_data/' + 'record_segment_good_length_' + str(first_record) + '_' + str(last_record - 1) +'.csv'

# %%
record_segment_file_name
# Out:
# '../../../2_data/record_segment_good_length_4000_5999.csv'

# %%
record_path_local = '../../../2_data/record_path_mimic3_matched.csv'
record_root_url = 'https://physionet.org/content/mimic3wdb/1.0/matched'
record_path_url = record_root_url + '/RECORDS-waveforms'

signal_extract_name = 'PLETH'
signal_extract_minimum_length = 5 # the minimum length of the signal segment, in minutes

#record_root_url = 'https://archive.physionet.org/physiobank/database/mimic3wdb'
#record_path_url = record_root_url + '/RECORDS'

print('record_path_local: {}'.format(record_path_local))
print('record_root_url: {}'.format(record_root_url))
print('record_path_url: {}'.format(record_path_url))
# Out:
# record_path_local: ../../../2_data/record_path_mimic3_matched.csv
# record_root_url: https://physionet.org/content/mimic3wdb/1.0/matched
# record_path_url: https://physionet.org/content/mimic3wdb/1.0/matched/RECORDS-waveforms

# %%
def get_url_content(url, tag=None):
    
    '''
    This function scrapes a list of useful information from a given PhysioNet URL.
    If the URL address points to an HTML document, the information to be extracted is define by a tag.
    I found this address (https://hackersandslackers.com/scraping-urls-with-beautifulsoup/) usefull
      for details on how to scrape a web page
    '''
    
    headers = {
        'Access-Control-Allow-Origin': '*',
        'Access-Control-Allow-Methods': 'GET',
        'Access-Control-Allow-Headers': 'Content-Type',
        'Access-Control-Max-Age': '3600',
        'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0'
    }    
    
    req = requests.get(url, headers)
    soup = BeautifulSoup(req.content, 'html.parser')
    if '<!DOCTYPE html>' in str(soup):
        content = getattr(soup, str(tag)).getText()
        #content = soup.pre.getText()
    else:
        content = soup.getText()
    return content.splitlines()

# %%
tag = 'pre'
record_path_list = get_url_content(record_path_url, tag)
print(len(record_path_list))
for i in range(5):
    print('record_path: {}'.format(record_path_list[i]))
# Out:
# 22317
# record_path: p00/p000020/p000020-2183-04-28-17-47
# record_path: p00/p000030/p000030-2172-10-16-12-22
# record_path: p00/p000033/p000033-2116-12-24-12-35
# record_path: p00/p000033/p000033-2116-12-25-13-11
# record_path: p00/p000052/p000052-2191-01-10-02-21

# %%
tag = 'pre'
record_good_length_index = 0
for process_record_index in range(first_record, last_record):
        
    #print(process_record_index)
    record_path = record_path_list[process_record_index]
    print('processing record #: {}, record_path: {}'.format(process_record_index, record_path))
    
    #directory p04/p044083.
    directory = str(record_path.split("/")[0]) + '/' + str(record_path.split("/")[1])
    #print('directory: {}'.format(directory))
    
    intermediate_directory = str(record_path.split("/")[0])
    #print('intermediate_directory: {}'.format(intermediate_directory))
    subject_id = record_path.split("/")[1]
    subject_id = int(subject_id[1:])
    #print('subject_id: {}'.format(subject_id))
        
    master_waveform_header = record_root_url + '/' + record_path + '.hea'
    #print('master_waveform_header: {}'.format(master_waveform_header))
    
    target_url = master_waveform_header
    master_waveform_content = get_url_content(target_url, tag)
    #print('master_waveform_content: {}'.format(master_waveform_content))
    
    #print('       ...........\n')
    
    master_waveform_content_first_line = master_waveform_content[0].split(' ')
    record_length = int(master_waveform_content_first_line[3]) / int(master_waveform_content_first_line[2])
    #print('record_length (s): {}'.format(record_length))
    
    #print('       ...........\n')    
        
    waveform_layout_header = master_waveform_content[1].split(' ')[0]
    waveform_layout_header = waveform_layout_header + '.hea'
    waveform_layout_header = record_root_url + '/' + directory + '/' + waveform_layout_header
    #print('waveform_layout_header: {}'.format(waveform_layout_header))    
    target_url = waveform_layout_header
    waveform_layout_content = get_url_content(target_url, tag)
    #print('waveform_layout_content: {}'.format(waveform_layout_content))
        
    signal_names = [x.split(' ')[-1] for x in waveform_layout_content[1:-1]]
    #print('signal_names: {}'.format(signal_names))
    
    if signal_extract_name in signal_names and record_length > 60 * signal_extract_minimum_length: # and len(record_segments_path_list):      
        
        record_good_length_index += 1
        
        # Open the record_segment_file_name file with access mode 'a'
        record_segment_file_object = open(record_segment_file_name, 'a')

        # get the waveform record name
        waveform_record_name = [x.split(' ')[0].split('_') for x in master_waveform_content if '3' == x[0]][0][0]
        
        # get the waveform_record_state
        waveform_record_state = [(waveform_record_name + '_' in x) and not (waveform_record_name + '_layout' in x) 
                for x in master_waveform_content]

        # get the waveform_record_segment
        waveform_record_segment = [master_waveform_content[x].split(' ') for x, y in enumerate(waveform_record_state) if y]

        
        for segment_index in range(len(waveform_record_segment)):
            # number of samples: int(waveform_record_segment[segment_index][1])
            # sampling frequency: int(master_waveform_content_first_line[2])
            # length (in seconds) of the record segment: number of samples / sampling frequency
            
            if int(waveform_record_segment[segment_index][1]) / int(master_waveform_content_first_line[2]) > 60 * signal_extract_minimum_length:
                
                waveform_record_segment_good_length_root = directory + '/' +  waveform_record_segment[segment_index][0]
                print('  ' + str(record_good_length_index) + ',' + str(process_record_index) + ',' + waveform_record_segment_good_length_root)
                
                # Append the waveform_record_segment_good_length_root at the end of file record_segment_file_name
                record_segment_file_object.write(str(record_good_length_index) + ',' + str(process_record_index) + ',' + waveform_record_segment_good_length_root + '\n')

        #print('baubau_1')
        
        # Close the file record_segment_file_name
        record_segment_file_object.close()
        #break
        
    
    
    #print('       ...........\n')
    #index_of_last_record_processed = index_of_last_record_processed + 1
    print('  \nindex of last record processed successfully: {}'.format(process_record_index))  
    print('--------------------------------------')
# Out:
# processing record #: 4000, record_path: p01/p016392/p016392-2185-03-25-14-25
#
# index of last record processed successfully: 4000
# --------------------------------------
# processing record #: 4001, record_path: p01/p016399/p016399-2179-09-02-13-15
#
# index of last record processed successfully: 4001
# --------------------------------------
# processing record #: 4002, record_path: p01/p016399/p016399-2179-09-03-14-25
#
# index of last record processed successfully: 4002
# --------------------------------------
# processing record #: 4003, record_path: p01/p016399/p016399-2179-09-03-16-51
#
# index of last record processed successfully: 4003
# --------------------------------------
# processing record #: 4004, record_path: p01/p016399/p016399-2179-09-04-18-59
#
# index of last record processed successfully: 4004
# --------------------------------------
# processing record #: 4005, record_path: p01/p016423/p016423-2179-08-26-20-56
#
# index of last record processed successfully: 4005
# --------------------------------------
# processing record #: 4006, record_path: p01/p016423/p016423-2179-08-29-00-07
#
# index of last record processed successfully: 4006
# --------------------------------------
# processing record #: 4007, record_path: p01/p016436/p016436-2166-10-27-18-46
#
# index of last record processed successfully: 4007
# --------------------------------------
# processing record #: 4008, record_path: p01/p016436/p016436-2166-10-28-17-44
#
# index of last record processed successfully: 4008
# --------------------------------------
# processing record #: 4009, record_path: p01/p016436/p016436-2166-10-29-14-45
#
# index of last record processed successfully: 4009
# --------------------------------------
# processing record #: 4010, record_path: p01/p016447/p016447-2191-09-01-13-14
#
# index of last record processed successfully: 4010
# --------------------------------------
# processing record #: 4011, record_path: p01/p016447/p016447-2191-09-02-17-16
#
# index of last record processed successfully: 4011
# --------------------------------------
# processing record #: 4012, record_path: p01/p016455/p016455-2117-01-20-14-15
#
# index of last record processed successfully: 4012
# --------------------------------------
# processing record #: 4013, record_path: p01/p016455/p016455-2117-01-29-16-48
#
# index of last record processed successfully: 4013
# --------------------------------------
# processing record #: 4014, record_path: p01/p016455/p016455-2118-06-04-20-44
#
# index of last record processed successfully: 4014
# --------------------------------------
# processing record #: 4015, record_path: p01/p016455/p016455-2118-06-06-09-22
#
# index of last record processed successfully: 4015
# --------------------------------------
# processing record #: 4016, record_path: p01/p016455/p016455-2118-06-08-13-18
#
# index of last record processed successfully: 4016
# --------------------------------------
# processing record #: 4017, record_path: p01/p016455/p016455-2118-06-10-19-23
#
# index of last record processed successfully: 4017
# --------------------------------------
# processing record #: 4018, record_path: p01/p016463/p016463-2129-02-22-05-04
#   1,4018,p01/p016463/3615184_0006
#   1,4018,p01/p016463/3615184_0008
#   1,4018,p01/p016463/3615184_0009
#   1,4018,p01/p016463/3615184_0016
#   1,4018,p01/p016463/3615184_0017
#   1,4018,p01/p016463/3615184_0019
#   1,4018,p01/p016463/3615184_0021
#   1,4018,p01/p016463/3615184_0024
#   1,4018,p01/p016463/3615184_0026
#
# index of last record processed successfully: 4018
# --------------------------------------
# processing record #: 4019, record_path: p01/p016490/p016490-2144-11-18-18-25
#
# index of last record processed successfully: 4019
# --------------------------------------
# processing record #: 4020, record_path: p01/p016492/p016492-2179-02-25-17-42
#
# index of last record processed successfully: 4020
# --------------------------------------
# processing record #: 4021, record_path: p01/p016499/p016499-2181-05-24-02-01
#
# index of last record processed successfully: 4021
# --------------------------------------
# processing record #: 4022, record_path: p01/p016504/p016504-2188-12-18-17-02
#
# index of last record processed successfully: 4022
# --------------------------------------
# processing record #: 4023, record_path: p01/p016504/p016504-2188-12-19-16-24
#
# index of last record processed successfully: 4023
# --------------------------------------
# processing record #: 4024, record_path: p01/p016511/p016511-2194-10-14-15-57
#
# index of last record processed successfully: 4024
# --------------------------------------
# processing record #: 4025, record_path: p01/p016511/p016511-2194-10-16-18-14
#
# index of last record processed successfully: 4025
# --------------------------------------
# processing record #: 4026, record_path: p01/p016511/p016511-2194-10-19-15-08
#
# index of last record processed successfully: 4026
# --------------------------------------
# processing record #: 4027, record_path: p01/p016511/p016511-2194-10-29-17-37
#
# index of last record processed successfully: 4027
# --------------------------------------
# processing record #: 4028, record_path: p01/p016516/p016516-2137-07-20-18-07
#
# index of last record processed successfully: 4028
# --------------------------------------
# processing record #: 4029, record_path: p01/p016533/p016533-2188-07-05-13-52
#
# index of last record processed successfully: 4029
# --------------------------------------
# processing record #: 4030, record_path: p01/p016533/p016533-2188-07-06-12-03
#
# index of last record processed successfully: 4030
# --------------------------------------
# processing record #: 4031, record_path: p01/p016550/p016550-2155-07-23-13-19
#
# index of last record processed successfully: 4031
# --------------------------------------
# processing record #: 4032, record_path: p01/p016550/p016550-2155-09-15-20-59
#
# index of last record processed successfully: 4032
# --------------------------------------
# processing record #: 4033, record_path: p01/p016550/p016550-2155-09-15-23-04
#
# index of last record processed successfully: 4033
# --------------------------------------
# processing record #: 4034, record_path: p01/p016554/p016554-2164-06-09-19-44
#
# index of last record processed successfully: 4034
# --------------------------------------
# processing record #: 4035, record_path: p01/p016554/p016554-2165-05-17-04-58
#   2,4035,p01/p016554/3826157_0005
#   2,4035,p01/p016554/3826157_0007
#   2,4035,p01/p016554/3826157_0009
#
# index of last record processed successfully: 4035
# --------------------------------------
# processing record #: 4036, record_path: p01/p016560/p016560-2110-07-18-14-16
#
# index of last record processed successfully: 4036
# --------------------------------------
# processing record #: 4037, record_path: p01/p016560/p016560-2110-07-19-21-08
#   3,4037,p01/p016560/3868489_0002
#
# index of last record processed successfully: 4037
# --------------------------------------
# processing record #: 4038, record_path: p01/p016560/p016560-2110-07-25-17-14
#
# index of last record processed successfully: 4038
# --------------------------------------
# processing record #: 4039, record_path: p01/p016560/p016560-2113-09-07-06-29
#   4,4039,p01/p016560/3994368_0007
#   4,4039,p01/p016560/3994368_0008
#   4,4039,p01/p016560/3994368_0011
#   4,4039,p01/p016560/3994368_0013
#   4,4039,p01/p016560/3994368_0015
#   4,4039,p01/p016560/3994368_0017
#
# index of last record processed successfully: 4039
# --------------------------------------
# processing record #: 4040, record_path: p01/p016560/p016560-2115-09-28-00-42
#   5,4040,p01/p016560/3413431_0006
#   5,4040,p01/p016560/3413431_0008
#   5,4040,p01/p016560/3413431_0010
#   5,4040,p01/p016560/3413431_0018
#   5,4040,p01/p016560/3413431_0021
#   5,4040,p01/p016560/3413431_0022
#   5,4040,p01/p016560/3413431_0023
#   5,4040,p01/p016560/3413431_0025
#   5,4040,p01/p016560/3413431_0027
#   5,4040,p01/p016560/3413431_0033
#   5,4040,p01/p016560/3413431_0035
#   5,4040,p01/p016560/3413431_0038
#   5,4040,p01/p016560/3413431_0040
#   5,4040,p01/p016560/3413431_0042
#   5,4040,p01/p016560/3413431_0044
#   5,4040,p01/p016560/3413431_0046
#   5,4040,p01/p016560/3413431_0048
#   5,4040,p01/p016560/3413431_0050
#
# index of last record processed successfully: 4040
# --------------------------------------
# processing record #: 4041, record_path: p01/p016565/p016565-2137-04-17-01-51
#
#   6,4049,p01/p016590/3275119_0161
#   6,4049,p01/p016590/3275119_0163
#   6,4049,p01/p016590/3275119_0167
#   6,4049,p01/p016590/3275119_0169
#   6,4049,p01/p016590/3275119_0171
#   6,4049,p01/p016590/3275119_0173
#
# index of last record processed successfully: 4049
# --------------------------------------
# processing record #: 4050, record_path: p01/p016590/p016590-2181-06-05-19-16
#   7,4050,p01/p016590/3722172_0004
#   7,4050,p01/p016590/3722172_0005
#   7,4050,p01/p016590/3722172_0006
#   7,4050,p01/p016590/3722172_0008
#   7,4050,p01/p016590/3722172_0010
#   7,4050,p01/p016590/3722172_0012
#
# index of last record processed successfully: 4050
# --------------------------------------
# processing record #: 4051, record_path: p01/p016592/p016592-2201-11-07-19-58
#
# index of last record processed successfully: 4051
# --------------------------------------
# processing record #: 4052, record_path: p01/p016607/p016607-2118-03-18-14-04
#
# index of last record processed successfully: 4052
# --------------------------------------
# processing record #: 4053, record_path: p01/p016608/p016608-2148-05-31-15-17
#
# index of last record processed successfully: 4053
# --------------------------------------
# processing record #: 4054, record_path: p01/p016608/p016608-2148-06-01-17-58
#
# index of last record processed successfully: 4054
# --------------------------------------
# processing record #: 4055, record_path: p01/p016619/p016619-2176-07-26-17-37
#   8,4055,p01/p016619/3444101_0001
#   8,4055,p01/p016619/3444101_0005
#   8,4055,p01/p016619/3444101_0007
#   8,4055,p01/p016619/3444101_0011
#   8,4055,p01/p016619/3444101_0017
#   8,4055,p01/p016619/3444101_0019
#   8,4055,p01/p016619/3444101_0022
#   8,4055,p01/p016619/3444101_0024
#   8,4055,p01/p016619/3444101_0025
#   8,4055,p01/p016619/3444101_0026
#   8,4055,p01/p016619/3444101_0028
#   8,4055,p01/p016619/3444101_0031
#   8,4055,p01/p016619/3444101_0034
#   8,4055,p01/p016619/3444101_0036
#
# index of last record processed successfully: 4055
# --------------------------------------
# processing record #: 4056, record_path: p01/p016637/p016637-2137-06-20-01-41
#   9,4056,p01/p016637/3077264_0003
#   9,4056,p01/p016637/3077264_0008
#   9,4056,p01/p016637/3077264_0010
#   9,4056,p01/p016637/3077264_0012
#   9,4056,p01/p016637/3077264_0014
#   9,4056,p01/p016637/3077264_0016
#   9,4056,p01/p016637/3077264_0019
#   9,4056,p01/p016637/3077264_0022
#   9,4056,p01/p016637/3077264_0024
#
# index of last record processed successfully: 4056
# --------------------------------------
# processing record #: 4057, record_path: p01/p016639/p016639-2108-09-27-12-49
#
# index of last record processed successfully: 4057
# --------------------------------------
# processing record #: 4058, record_path: p01/p016639/p016639-2108-09-27-16-33
#
# index of last record processed successfully: 4058
# --------------------------------------
# processing record #: 4059, record_path: p01/p016640/p016640-2176-11-18-17-06
#
# index of last record processed successfully: 4059
# --------------------------------------
# processing record #: 4060, record_path: p01/p016642/p016642-2157-10-02-19-03
#   10,4060,p01/p016642/3384951_0005
#   10,4060,p01/p016642/3384951_0006
#   10,4060,p01/p016642/3384951_0007
#   10,4060,p01/p016642/3384951_0009
#   10,4060,p01/p016642/3384951_0011
#   10,4060,p01/p016642/3384951_0014
#   10,4060,p01/p016642/3384951_0017
#   10,4060,p01/p016642/3384951_0022
#   10,4060,p01/p016642/3384951_0025
#   10,4060,p01/p016642/3384951_0026
#   10,4060,p01/p016642/3384951_0029
#   10,4060,p01/p016642/3384951_0032
#
# index of last record processed successfully: 4060
# --------------------------------------
# processing record #: 4061, record_path: p01/p016642/p016642-2167-06-15-18-51
#
# index of last record processed successfully: 4061
# --------------------------------------
# processing record #: 4062, record_path: p01/p016666/p016666-2156-06-04-19-31
#
# index of last record processed successfully: 4062
# --------------------------------------
# processing record #: 4063, record_path: p01/p016677/p016677-2121-12-23-17-30
#
# index of last record processed successfully: 4063
# --------------------------------------
# processing record #: 4064, record_path: p01/p016684/p016684-2188-01-29-00-06
#   11,4064,p01/p016684/3660898_0002
#   11,4064,p01/p016684/3660898_0005
#   11,4064,p01/p016684/3660898_0006
#   11,4064,p01/p016684/3660898_0009
#   11,4064,p01/p016684/3660898_0012
#
# index of last record processed successfully: 4064
# --------------------------------------
# processing record #: 4065, record_path: p01/p016685/p016685-2173-07-22-19-55
#
# index of last record processed successfully: 4065
# --------------------------------------
# processing record #: 4066, record_path: p01/p016691/p016691-2115-11-19-13-39
#
# index of last record processed successfully: 4066
# --------------------------------------
# processing record #: 4067, record_path: p01/p016709/p016709-2195-10-01-13-16
#
# index of last record processed successfully: 4067
# --------------------------------------
# processing record #: 4068, record_path: p01/p016709/p016709-2195-10-09-13-11
#
# index of last record processed successfully: 4068
# --------------------------------------
# processing record #: 4069, record_path: p01/p016715/p016715-2175-07-20-18-21
#
# index of last record processed successfully: 4069
# --------------------------------------
# processing record #: 4070, record_path: p01/p016723/p016723-2171-10-07-20-20
#
# index of last record processed successfully: 4070
# --------------------------------------
# processing record #: 4071, record_path: p01/p016727/p016727-2158-09-05-13-37
#
# index of last record processed successfully: 4071
# --------------------------------------
# processing record #: 4072, record_path: p01/p016727/p016727-2160-08-13-00-24
#
# index of last record processed successfully: 4072
# --------------------------------------
# processing record #: 4073, record_path: p01/p016727/p016727-2160-12-30-16-00
#
# index of last record processed successfully: 4073
# --------------------------------------
# processing record #: 4074, record_path: p01/p016748/p016748-2120-07-29-11-23
#
# index of last record processed successfully: 4074
# --------------------------------------
# processing record #: 4075, record_path: p01/p016775/p016775-2188-02-24-22-23
#
# index of last record processed successfully: 4075
# --------------------------------------
# processing record #: 4076, record_path: p01/p016775/p016775-2188-02-26-10-32
#
# index of last record processed successfully: 4076
# --------------------------------------
# processing record #: 4077, record_path: p01/p016775/p016775-2188-02-26-11-34
#
# index of last record processed successfully: 4077
# --------------------------------------
# processing record #: 4078, record_path: p01/p016775/p016775-2188-02-26-12-47
#
# index of last record processed successfully: 4078
# --------------------------------------
# processing record #: 4079, record_path: p01/p016776/p016776-2139-11-19-19-06
#
# index of last record processed successfully: 4079
# --------------------------------------
# processing record #: 4080, record_path: p01/p016798/p016798-2173-05-19-20-15
#   14,4088,p01/p016821/3663540_0140
#
# index of last record processed successfully: 4088
# --------------------------------------
# processing record #: 4089, record_path: p01/p016827/p016827-2102-12-12-15-57
#
# index of last record processed successfully: 4089
# --------------------------------------
# processing record #: 4090, record_path: p01/p016839/p016839-2102-09-04-01-57
#
# index of last record processed successfully: 4090
# --------------------------------------
# processing record #: 4091, record_path: p01/p016839/p016839-2102-09-05-17-05
#
# index of last record processed successfully: 4091
# --------------------------------------
# processing record #: 4092, record_path: p01/p016839/p016839-2102-09-06-10-25
#
# index of last record processed successfully: 4092
# --------------------------------------
# processing record #: 4093, record_path: p01/p016849/p016849-2106-09-18-14-52
#
# index of last record processed successfully: 4093
# --------------------------------------
# processing record #: 4094, record_path: p01/p016853/p016853-2178-05-25-17-37
#
# index of last record processed successfully: 4094
# --------------------------------------
# processing record #: 4095, record_path: p01/p016856/p016856-2179-08-13-13-45
#
# index of last record processed successfully: 4095
# --------------------------------------
# processing record #: 4096, record_path: p01/p016856/p016856-2179-09-01-11-44
#   15,4096,p01/p016856/3787914_0008
#   15,4096,p01/p016856/3787914_0009
#   15,4096,p01/p016856/3787914_0011
#   15,4096,p01/p016856/3787914_0014
#   15,4096,p01/p016856/3787914_0016
#
# index of last record processed successfully: 4096
# --------------------------------------
# processing record #: 4097, record_path: p01/p016856/p016856-2179-09-01-17-39
#   16,4097,p01/p016856/3175730_0010
#   16,4097,p01/p016856/3175730_0012
#   16,4097,p01/p016856/3175730_0024
#   16,4097,p01/p016856/3175730_0030
#
# index of last record processed successfully: 4097
# --------------------------------------
# processing record #: 4098, record_path: p01/p016856/p016856-2179-10-13-12-59
#
# index of last record processed successfully: 4098
# --------------------------------------
# processing record #: 4099, record_path: p01/p016860/p016860-2128-11-16-23-18
#
# index of last record processed successfully: 4099
# --------------------------------------
# processing record #: 4100, record_path: p01/p016864/p016864-2143-05-27-00-53
#
# index of last record processed successfully: 4100
# --------------------------------------
# processing record #: 4101, record_path: p01/p016873/p016873-2106-07-12-12-09
#
# index of last record processed successfully: 4101
# --------------------------------------
# processing record #: 4102, record_path: p01/p016873/p016873-2106-07-12-20-04
#
# index of last record processed successfully: 4102
# --------------------------------------
# processing record #: 4103, record_path: p01/p016874/p016874-2183-10-18-21-12
#
# index of last record processed successfully: 4103
# --------------------------------------
# processing record #: 4104, record_path: p01/p016874/p016874-2183-10-19-14-08
#
# index of last record processed successfully: 4104
# --------------------------------------
# processing record #: 4105, record_path: p01/p016874/p016874-2183-10-20-17-46
#
# index of last record processed successfully: 4105
# --------------------------------------
# processing record #: 4106, record_path: p01/p016874/p016874-2183-10-21-19-31
#
# index of last record processed successfully: 4106
# --------------------------------------
# processing record #: 4107, record_path: p01/p016876/p016876-2181-04-11-10-35
#
# index of last record processed successfully: 4107
# --------------------------------------
# processing record #: 4108, record_path: p01/p016876/p016876-2181-04-11-12-35
#
# index of last record processed successfully: 4108
# --------------------------------------
# processing record #: 4109, record_path: p01/p016881/p016881-2164-12-27-21-31
#
# index of last record processed successfully: 4109
# --------------------------------------
# processing record #: 4110, record_path: p01/p016881/p016881-2164-12-28-15-02
#
# index of last record processed successfully: 4110
# --------------------------------------
# processing record #: 4111, record_path: p01/p016881/p016881-2164-12-29-16-25
#
# index of last record processed successfully: 4111
# --------------------------------------
# processing record #: 4112, record_path: p01/p016888/p016888-2154-09-13-07-38
#
# index of last record processed successfully: 4112
# --------------------------------------
# processing record #: 4113, record_path: p01/p016888/p016888-2154-09-13-09-48
#   18,4113,p01/p016888/3539990_0003
#   18,4113,p01/p016888/3539990_0004
#   18,4113,p01/p016888/3539990_0006
#   18,4113,p01/p016888/3539990_0008
#   18,4113,p01/p016888/3539990_0012
#   18,4113,p01/p016888/3539990_0015
#   18,4113,p01/p016888/3539990_0019
#   18,4113,p01/p016888/3539990_0020
#   18,4113,p01/p016888/3539990_0021
#
# index of last record processed successfully: 4113
# --------------------------------------
# processing record #: 4114, record_path: p01/p016888/p016888-2154-09-13-16-40
#
# index of last record processed successfully: 4114
# --------------------------------------
# processing record #: 4115, record_path: p01/p016909/p016909-2174-07-08-12-20
#
# index of last record processed successfully: 4115
# --------------------------------------
# processing record #: 4116, record_path: p01/p016909/p016909-2185-05-25-23-20
#   19,4116,p01/p016909/3458170_0002
#   19,4116,p01/p016909/3458170_0003
#   19,4116,p01/p016909/3458170_0004
#   19,4116,p01/p016909/3458170_0007
#
# index of last record processed successfully: 4116
# --------------------------------------
# processing record #: 4117, record_path: p01/p016909/p016909-2185-05-26-21-22
#   20,4117,p01/p016909/3076557_0001
#   20,4117,p01/p016909/3076557_0003
#   20,4117,p01/p016909/3076557_0005
#   20,4117,p01/p016909/3076557_0006
#   20,4117,p01/p016909/3076557_0008
#   20,4117,p01/p016909/3076557_0014
#   20,4117,p01/p016909/3076557_0015
#   20,4117,p01/p016909/3076557_0018
#
# index of last record processed successfully: 4117
# --------------------------------------
# processing record #: 4118, record_path: p01/p016909/p016909-2185-05-27-18-22
#
# index of last record processed successfully: 4118
# --------------------------------------
# processing record #: 4119, record_path: p01/p016916/p016916-2135-09-23-12-51
#
# index of last record processed successfully: 4119
# --------------------------------------
# processing record #: 4120, record_path: p01/p016924/p016924-2172-07-09-04-23
#
# index of last record processed successfully: 4120
# --------------------------------------
# processing record #: 4121, record_path: p01/p016924/p016924-2172-07-22-11-44
#
# index of last record processed successfully: 4121
# --------------------------------------
# processing record #: 4122, record_path: p01/p016924/p016924-2172-07-25-03-40
#
# index of last record processed successfully: 4122
# --------------------------------------
# processing record #: 4123, record_path: p01/p016927/p016927-2166-10-01-12-21
#
# index of last record processed successfully: 4123
# --------------------------------------
# processing record #: 4124, record_path: p01/p016932/p016932-2167-03-21-16-43
#
# index of last record processed successfully: 4124
# --------------------------------------
# processing record #: 4125, record_path: p01/p016932/p016932-2167-03-23-13-26
#
# index of last record processed successfully: 4125
# --------------------------------------
# processing record #: 4126, record_path: p01/p016949/p016949-2165-01-06-03-13
#
# index of last record processed successfully: 4126
# --------------------------------------
# processing record #: 4127, record_path: p01/p016961/p016961-2112-11-02-17-15
#
# index of last record processed successfully: 4127
# --------------------------------------
# processing record #: 4128, record_path: p01/p016967/p016967-2116-03-19-18-40
#
# index of last record processed successfully: 4128
# --------------------------------------
# processing record #: 4129, record_path: p01/p016967/p016967-2116-03-20-18-11
#
# index of last record processed successfully: 4129
# --------------------------------------
# processing record #: 4130, record_path: p01/p016967/p016967-2116-03-22-12-09
#
# index of last record processed successfully: 4130
# --------------------------------------
# processing record #: 4131, record_path: p01/p016992/p016992-2114-02-25-20-05
#
# index of last record processed successfully: 4131
# --------------------------------------
# processing record #: 4132, record_path: p01/p016992/p016992-2114-02-25-20-15
#
# index of last record processed successfully: 4132
# --------------------------------------
# processing record #: 4133, record_path: p01/p016992/p016992-2115-02-07-14-25
#   21,4133,p01/p016992/3953488_0001
#   21,4133,p01/p016992/3953488_0003
#   21,4133,p01/p016992/3953488_0006
#
# index of last record processed successfully: 4133
# --------------------------------------
# processing record #: 4134, record_path: p01/p016992/p016992-2115-02-08-15-56
#
# index of last record processed successfully: 4134
# --------------------------------------
# processing record #: 4135, record_path: p01/p017002/p017002-2153-04-16-21-38
#   22,4135,p01/p017002/3270227_0002
#   22,4135,p01/p017002/3270227_0003
#
# index of last record processed successfully: 4135
# --------------------------------------
# processing record #: 4136, record_path: p01/p017018/p017018-2128-03-06-18-13
#
# index of last record processed successfully: 4136
# --------------------------------------
# processing record #: 4137, record_path: p01/p017018/p017018-2128-03-15-11-38
#
# index of last record processed successfully: 4137
# --------------------------------------
# processing record #: 4138, record_path: p01/p017021/p017021-2173-10-14-14-43
#
# index of last record processed successfully: 4138
# --------------------------------------
# processing record #: 4139, record_path: p01/p017026/p017026-2163-04-21-16-02
#
# index of last record processed successfully: 4139
# --------------------------------------
# processing record #: 4140, record_path: p01/p017026/p017026-2173-06-30-23-05
#   23,4140,p01/p017026/3248798_0001
#   23,4140,p01/p017026/3248798_0003
#   23,4140,p01/p017026/3248798_0004
#   23,4140,p01/p017026/3248798_0007
#   23,4140,p01/p017026/3248798_0010
#   23,4140,p01/p017026/3248798_0011
#   23,4140,p01/p017026/3248798_0014
#   23,4140,p01/p017026/3248798_0016
#   23,4140,p01/p017026/3248798_0017
#   23,4140,p01/p017026/3248798_0020
#   23,4140,p01/p017026/3248798_0023
#   23,4140,p01/p017026/3248798_0026
#   23,4140,p01/p017026/3248798_0030
#   23,4140,p01/p017026/3248798_0036
#   23,4140,p01/p017026/3248798_0038
#   23,4140,p01/p017026/3248798_0039
#   23,4140,p01/p017026/3248798_0040
#   23,4140,p01/p017026/3248798_0043
#
# index of last record processed successfully: 4140
# --------------------------------------
# processing record #: 4141, record_path: p01/p017026/p017026-2173-07-10-09-22
#   24,4141,p01/p017026/3411990_0005
#   24,4141,p01/p017026/3411990_0006
#   24,4141,p01/p017026/3411990_0012
#   24,4141,p01/p017026/3411990_0013
#   24,4141,p01/p017026/3411990_0014
#   24,4141,p01/p017026/3411990_0015
#   24,4141,p01/p017026/3411990_0018
#   24,4141,p01/p017026/3411990_0028
#   24,4141,p01/p017026/3411990_0029
#   24,4141,p01/p017026/3411990_0031
#   24,4141,p01/p017026/3411990_0034
#   24,4141,p01/p017026/3411990_0037
#   24,4141,p01/p017026/3411990_0040
#   24,4141,p01/p017026/3411990_0041
#   24,4141,p01/p017026/3411990_0043
#   24,4141,p01/p017026/3411990_0046
#   24,4141,p01/p017026/3411990_0049
#   24,4141,p01/p017026/3411990_0052
#   24,4141,p01/p017026/3411990_0055
#   24,4141,p01/p017026/3411990_0058
#   24,4141,p01/p017026/3411990_0061
#   24,4141,p01/p017026/3411990_0064
#   24,4141,p01/p017026/3411990_0065
#   24,4141,p01/p017026/3411990_0068
#   24,4141,p01/p017026/3411990_0071
#   24,4141,p01/p017026/3411990_0073
#   24,4141,p01/p017026/3411990_0077
#   24,4141,p01/p017026/3411990_0083
#   24,4141,p01/p017026/3411990_0084
#   24,4141,p01/p017026/3411990_0086
#   24,4141,p01/p017026/3411990_0089
#   24,4141,p01/p017026/3411990_0090
#   24,4141,p01/p017026/3411990_0091
#   24,4141,p01/p017026/3411990_0092
#   24,4141,p01/p017026/3411990_0095
#   24,4141,p01/p017026/3411990_0098
#   24,4141,p01/p017026/3411990_0101
#   24,4141,p01/p017026/3411990_0103
#   24,4141,p01/p017026/3411990_0106
#   24,4141,p01/p017026/3411990_0109
#   24,4141,p01/p017026/3411990_0115
#   24,4141,p01/p017026/3411990_0117
#   24,4141,p01/p017026/3411990_0118
#   24,4141,p01/p017026/3411990_0121
#   24,4141,p01/p017026/3411990_0123
#   24,4141,p01/p017026/3411990_0124
#   24,4141,p01/p017026/3411990_0127
#   24,4141,p01/p017026/3411990_0130
#   24,4141,p01/p017026/3411990_0133
#   24,4141,p01/p017026/3411990_0139
#   24,4141,p01/p017026/3411990_0141
#
# index of last record processed successfully: 4141
# --------------------------------------
# processing record #: 4142, record_path: p01/p017028/p017028-2104-12-14-21-29
#
# index of last record processed successfully: 4142
# --------------------------------------
# processing record #: 4143, record_path: p01/p017038/p017038-2113-03-01-19-03
#
# index of last record processed successfully: 4143
# --------------------------------------
# processing record #: 4144, record_path: p01/p017041/p017041-2178-03-23-14-22
#
# index of last record processed successfully: 4144
# --------------------------------------
# processing record #: 4145, record_path: p01/p017041/p017041-2178-03-23-18-23
#
# index of last record processed successfully: 4145
# --------------------------------------
# processing record #: 4146, record_path: p01/p017054/p017054-2115-04-20-09-59
#
# index of last record processed successfully: 4146
# --------------------------------------
# processing record #: 4147, record_path: p01/p017058/p017058-2150-07-04-01-17
#
# index of last record processed successfully: 4147
# --------------------------------------
# processing record #: 4148, record_path: p01/p017069/p017069-2188-01-14-12-22
#
# index of last record processed successfully: 4148
# --------------------------------------
# processing record #: 4149, record_path: p01/p017069/p017069-2188-01-15-19-36
#
# index of last record processed successfully: 4149
# --------------------------------------
# processing record #: 4150, record_path: p01/p017072/p017072-2142-12-09-19-54
# processing record #: 4164, record_path: p01/p017122/p017122-2141-04-08-14-49
#
# index of last record processed successfully: 4164
# --------------------------------------
# processing record #: 4165, record_path: p01/p017122/p017122-2141-04-20-17-48
#
# index of last record processed successfully: 4165
# --------------------------------------
# processing record #: 4166, record_path: p01/p017122/p017122-2141-05-05-15-10
#
# index of last record processed successfully: 4166
# --------------------------------------
# processing record #: 4167, record_path: p01/p017122/p017122-2141-05-23-20-11
#   26,4167,p01/p017122/3908854_0002
#   26,4167,p01/p017122/3908854_0004
#   26,4167,p01/p017122/3908854_0005
#   26,4167,p01/p017122/3908854_0006
#   26,4167,p01/p017122/3908854_0008
#   26,4167,p01/p017122/3908854_0010
#   26,4167,p01/p017122/3908854_0012
#   26,4167,p01/p017122/3908854_0014
#   26,4167,p01/p017122/3908854_0016
#   26,4167,p01/p017122/3908854_0020
#   26,4167,p01/p017122/3908854_0021
#   26,4167,p01/p017122/3908854_0022
#   26,4167,p01/p017122/3908854_0023
#
# index of last record processed successfully: 4167
# --------------------------------------
# processing record #: 4168, record_path: p01/p017128/p017128-2187-11-07-17-51
#   27,4168,p01/p017128/3870378_0002
#   27,4168,p01/p017128/3870378_0014
#   27,4168,p01/p017128/3870378_0028
#   27,4168,p01/p017128/3870378_0029
#   27,4168,p01/p017128/3870378_0033
#   27,4168,p01/p017128/3870378_0035
#   27,4168,p01/p017128/3870378_0036
#
# index of last record processed successfully: 4168
# --------------------------------------
# processing record #: 4169, record_path: p01/p017128/p017128-2187-11-08-17-47
#   28,4169,p01/p017128/3433951_0001
#   28,4169,p01/p017128/3433951_0004
#   28,4169,p01/p017128/3433951_0007
#   28,4169,p01/p017128/3433951_0010
#   28,4169,p01/p017128/3433951_0013
#   28,4169,p01/p017128/3433951_0015
#   28,4169,p01/p017128/3433951_0016
#   28,4169,p01/p017128/3433951_0021
#   28,4169,p01/p017128/3433951_0024
#   28,4169,p01/p017128/3433951_0027
#   28,4169,p01/p017128/3433951_0029
#   28,4169,p01/p017128/3433951_0030
#   28,4169,p01/p017128/3433951_0033
#   28,4169,p01/p017128/3433951_0042
#   28,4169,p01/p017128/3433951_0044
#
# index of last record processed successfully: 4169
# --------------------------------------
# processing record #: 4170, record_path: p01/p017128/p017128-2187-11-12-11-59
#
# index of last record processed successfully: 4170
# --------------------------------------
# processing record #: 4171, record_path: p01/p017128/p017128-2187-11-12-13-59
#
# index of last record processed successfully: 4171
# --------------------------------------
# processing record #: 4172, record_path: p01/p017128/p017128-2187-11-12-17-52
#
# index of last record processed successfully: 4172
# --------------------------------------
# processing record #: 4173, record_path: p01/p017133/p017133-2160-07-24-06-26
#
# index of last record processed successfully: 4173
# --------------------------------------
# processing record #: 4174, record_path: p01/p017133/p017133-2160-09-10-09-42
#
# index of last record processed successfully: 4174
# --------------------------------------
# processing record #: 4175, record_path: p01/p017133/p017133-2161-12-20-22-45
#   29,4175,p01/p017133/3698162_0004
#
# index of last record processed successfully: 4175
# --------------------------------------
# processing record #: 5927, record_path: p02/p024387/p024387-2187-08-28-19-01
#
# index of last record processed successfully: 5927
# --------------------------------------
# processing record #: 5928, record_path: p02/p024387/p024387-2187-08-28-22-25
#
# index of last record processed successfully: 5928
# --------------------------------------
# processing record #: 5929, record_path: p02/p024387/p024387-2187-09-01-03-23
#   381,5929,p02/p024387/3181450_0004
#   381,5929,p02/p024387/3181450_0005
#   381,5929,p02/p024387/3181450_0007
#   381,5929,p02/p024387/3181450_0008
#   381,5929,p02/p024387/3181450_0009
#   381,5929,p02/p024387/3181450_0012
#   381,5929,p02/p024387/3181450_0014
#   381,5929,p02/p024387/3181450_0016
#   381,5929,p02/p024387/3181450_0017
#   381,5929,p02/p024387/3181450_0018
#   381,5929,p02/p024387/3181450_0021
#   381,5929,p02/p024387/3181450_0022
#   381,5929,p02/p024387/3181450_0025
#   381,5929,p02/p024387/3181450_0028
#   381,5929,p02/p024387/3181450_0031
#   381,5929,p02/p024387/3181450_0040
#   381,5929,p02/p024387/3181450_0042
#   381,5929,p02/p024387/3181450_0043
#   381,5929,p02/p024387/3181450_0045
#
# index of last record processed successfully: 5929
# --------------------------------------
# processing record #: 5930, record_path: p02/p024411/p024411-2123-09-14-06-32
#
# index of last record processed successfully: 5930
# --------------------------------------
# processing record #: 5931, record_path: p02/p024417/p024417-2187-11-07-14-28
#
# index of last record processed successfully: 5931
# --------------------------------------
# processing record #: 5932, record_path: p02/p024417/p024417-2187-11-09-18-21
#
# index of last record processed successfully: 5932
# --------------------------------------
# processing record #: 5933, record_path: p02/p024431/p024431-2197-08-30-01-33
#
# index of last record processed successfully: 5933
# --------------------------------------
# processing record #: 5934, record_path: p02/p024431/p024431-2197-09-03-17-55
#
# index of last record processed successfully: 5934
# --------------------------------------
# processing record #: 5935, record_path: p02/p024431/p024431-2197-09-04-16-54
#
# index of last record processed successfully: 5935
# --------------------------------------
# processing record #: 5936, record_path: p02/p024438/p024438-2102-03-17-22-54
#
# index of last record processed successfully: 5936
# --------------------------------------
# processing record #: 5937, record_path: p02/p024438/p024438-2102-03-18-20-59
#
# index of last record processed successfully: 5937
# --------------------------------------
# processing record #: 5938, record_path: p02/p024443/p024443-2128-02-02-08-56
#
# index of last record processed successfully: 5938
# --------------------------------------
# processing record #: 5939, record_path: p02/p024446/p024446-2111-11-10-11-03
#
# index of last record processed successfully: 5939
# --------------------------------------
# processing record #: 5940, record_path: p02/p024446/p024446-2111-11-10-11-08
#
# index of last record processed successfully: 5940
# --------------------------------------
# processing record #: 5941, record_path: p02/p024447/p024447-2152-10-27-16-09
#
# index of last record processed successfully: 5941
# --------------------------------------
# processing record #: 5942, record_path: p02/p024455/p024455-2178-02-27-04-24
#
# index of last record processed successfully: 5942
# --------------------------------------
# processing record #: 5943, record_path: p02/p024455/p024455-2187-08-23-17-40
#   382,5943,p02/p024455/3822948_0005
#   382,5943,p02/p024455/3822948_0007
#   382,5943,p02/p024455/3822948_0009
#   382,5943,p02/p024455/3822948_0011
#   382,5943,p02/p024455/3822948_0014
#   382,5943,p02/p024455/3822948_0017
#   382,5943,p02/p024455/3822948_0019
#   382,5943,p02/p024455/3822948_0023
#
# index of last record processed successfully: 5943
# --------------------------------------
# processing record #: 5944, record_path: p02/p024457/p024457-2193-09-10-13-42
#
# index of last record processed successfully: 5944
# --------------------------------------
# processing record #: 5945, record_path: p02/p024460/p024460-2175-01-01-14-53
#
# index of last record processed successfully: 5945
# --------------------------------------
# processing record #: 5946, record_path: p02/p024460/p024460-2175-01-01-16-35
#
# index of last record processed successfully: 5946
# --------------------------------------
# processing record #: 5947, record_path: p02/p024460/p024460-2175-01-04-01-21
#
# index of last record processed successfully: 5947
# --------------------------------------
# processing record #: 5948, record_path: p02/p024461/p024461-2107-03-26-03-34
#
# index of last record processed successfully: 5948
# --------------------------------------
# processing record #: 5949, record_path: p02/p024475/p024475-2155-03-05-02-20
#
# index of last record processed successfully: 5949
# --------------------------------------
# processing record #: 5950, record_path: p02/p024477/p024477-2195-12-11-11-39
#
# index of last record processed successfully: 5950
# --------------------------------------
# processing record #: 5951, record_path: p02/p024477/p024477-2195-12-14-19-20
#   383,5951,p02/p024477/3776031_0009
#   383,5951,p02/p024477/3776031_0010
#   383,5951,p02/p024477/3776031_0012
#   383,5951,p02/p024477/3776031_0013
#   383,5951,p02/p024477/3776031_0015
#   383,5951,p02/p024477/3776031_0017
#   383,5951,p02/p024477/3776031_0019
#   383,5951,p02/p024477/3776031_0022
#
# index of last record processed successfully: 5951
# --------------------------------------
# processing record #: 5952, record_path: p02/p024477/p024477-2195-12-15-20-00
#   384,5952,p02/p024477/3597767_0002
#   384,5952,p02/p024477/3597767_0003
#   384,5952,p02/p024477/3597767_0010
#   384,5952,p02/p024477/3597767_0011
#   384,5952,p02/p024477/3597767_0014
#   384,5952,p02/p024477/3597767_0020
#
# index of last record processed successfully: 5952
# --------------------------------------
# processing record #: 5953, record_path: p02/p024477/p024477-2196-04-12-00-48
#
# index of last record processed successfully: 5953
# --------------------------------------
# processing record #: 5954, record_path: p02/p024477/p024477-2196-04-12-03-11
#
# index of last record processed successfully: 5954
# --------------------------------------
# processing record #: 5955, record_path: p02/p024477/p024477-2196-04-15-14-36
#
# index of last record processed successfully: 5955
# --------------------------------------
# processing record #: 5956, record_path: p02/p024477/p024477-2198-01-04-13-34
#
# index of last record processed successfully: 5956
# --------------------------------------
# processing record #: 5957, record_path: p02/p024477/p024477-2198-01-04-17-30
#   385,5957,p02/p024477/3075431_0001
#   385,5957,p02/p024477/3075431_0004
#   385,5957,p02/p024477/3075431_0011
#   385,5957,p02/p024477/3075431_0013
#   385,5957,p02/p024477/3075431_0017
#   385,5957,p02/p024477/3075431_0024
#   385,5957,p02/p024477/3075431_0035
#   385,5957,p02/p024477/3075431_0036
#   385,5957,p02/p024477/3075431_0042
#   385,5957,p02/p024477/3075431_0045
#   385,5957,p02/p024477/3075431_0049
#   385,5957,p02/p024477/3075431_0053
#   385,5957,p02/p024477/3075431_0055
#   385,5957,p02/p024477/3075431_0057
#   385,5957,p02/p024477/3075431_0061
#   385,5957,p02/p024477/3075431_0063
#   385,5957,p02/p024477/3075431_0065
#   385,5957,p02/p024477/3075431_0070
#   385,5957,p02/p024477/3075431_0076
#   385,5957,p02/p024477/3075431_0081
#   385,5957,p02/p024477/3075431_0085
#   385,5957,p02/p024477/3075431_0089
#   385,5957,p02/p024477/3075431_0097
#   385,5957,p02/p024477/3075431_0099
#   385,5957,p02/p024477/3075431_0103
#   385,5957,p02/p024477/3075431_0107
#   385,5957,p02/p024477/3075431_0114
#   385,5957,p02/p024477/3075431_0118
#   385,5957,p02/p024477/3075431_0120
#   385,5957,p02/p024477/3075431_0125
#
# index of last record processed successfully: 5957
# --------------------------------------
# processing record #: 5958, record_path: p02/p024477/p024477-2198-01-04-19-12
#
# index of last record processed successfully: 5958
# --------------------------------------
# processing record #: 5959, record_path: p02/p024508/p024508-2195-10-23-15-05
#
# index of last record processed successfully: 5959
# --------------------------------------
# processing record #: 5960, record_path: p02/p024508/p024508-2195-10-25-14-39
#
# index of last record processed successfully: 5960
# --------------------------------------
# processing record #: 5961, record_path: p02/p024508/p024508-2195-10-26-19-08
#
# index of last record processed successfully: 5961
# --------------------------------------
# processing record #: 5962, record_path: p02/p024514/p024514-2192-12-30-10-09
#
# index of last record processed successfully: 5962
# --------------------------------------
# processing record #: 5963, record_path: p02/p024532/p024532-2179-11-01-17-26
#
# index of last record processed successfully: 5963
# --------------------------------------
# processing record #: 5964, record_path: p02/p024532/p024532-2179-11-01-19-33
#
# index of last record processed successfully: 5964
# --------------------------------------
# processing record #: 5965, record_path: p02/p024532/p024532-2179-11-02-14-07
#
# index of last record processed successfully: 5965
# --------------------------------------
# processing record #: 5966, record_path: p02/p024548/p024548-2191-01-28-05-47
#
# index of last record processed successfully: 5966
# --------------------------------------
# processing record #: 5967, record_path: p02/p024552/p024552-2159-06-17-00-08
#
# index of last record processed successfully: 5967
# --------------------------------------
# processing record #: 5968, record_path: p02/p024556/p024556-2181-09-07-22-11
#
# index of last record processed successfully: 5968
# --------------------------------------
# processing record #: 5969, record_path: p02/p024556/p024556-2181-09-14-14-33
#
# index of last record processed successfully: 5969
# --------------------------------------
# processing record #: 5970, record_path: p02/p024559/p024559-2118-03-29-12-50
#
# index of last record processed successfully: 5970
# --------------------------------------
# processing record #: 5971, record_path: p02/p024559/p024559-2118-03-31-19-10
#
# index of last record processed successfully: 5971
# --------------------------------------
# processing record #: 5972, record_path: p02/p024560/p024560-2148-11-07-22-12
#
# index of last record processed successfully: 5972
# --------------------------------------
# processing record #: 5973, record_path: p02/p024560/p024560-2148-11-11-10-49
#
# index of last record processed successfully: 5973
# --------------------------------------
# processing record #: 5974, record_path: p02/p024560/p024560-2148-11-12-14-09
#
# index of last record processed successfully: 5974
# --------------------------------------
# processing record #: 5975, record_path: p02/p024562/p024562-2199-07-30-01-35
#
# index of last record processed successfully: 5975
# --------------------------------------
# processing record #: 5976, record_path: p02/p024562/p024562-2199-07-30-15-20
#
# index of last record processed successfully: 5976
# --------------------------------------
# processing record #: 5977, record_path: p02/p024562/p024562-2199-08-02-14-34
#
# index of last record processed successfully: 5977
# --------------------------------------
# processing record #: 5978, record_path: p02/p024562/p024562-2199-08-05-16-48
#
# index of last record processed successfully: 5978
# --------------------------------------
# processing record #: 5979, record_path: p02/p024567/p024567-2145-04-07-20-10
#
# index of last record processed successfully: 5979
# --------------------------------------
# processing record #: 5980, record_path: p02/p024567/p024567-2145-04-10-00-23
#
# index of last record processed successfully: 5980
# --------------------------------------
# processing record #: 5981, record_path: p02/p024567/p024567-2145-04-12-10-04
#
# index of last record processed successfully: 5981
# --------------------------------------
# processing record #: 5982, record_path: p02/p024569/p024569-2113-09-27-18-50
#
# index of last record processed successfully: 5982
# --------------------------------------
# processing record #: 5983, record_path: p02/p024569/p024569-2113-09-27-22-11
#
# index of last record processed successfully: 5983
# --------------------------------------
# processing record #: 5984, record_path: p02/p024569/p024569-2113-09-28-02-14
#
# index of last record processed successfully: 5984
# --------------------------------------
# processing record #: 5985, record_path: p02/p024573/p024573-2126-03-09-10-41
#
# index of last record processed successfully: 5985
# --------------------------------------
# processing record #: 5986, record_path: p02/p024573/p024573-2128-09-14-19-36
#
# index of last record processed successfully: 5986
# --------------------------------------
# processing record #: 5987, record_path: p02/p024573/p024573-2128-09-17-15-34
#
# index of last record processed successfully: 5987
# --------------------------------------
# processing record #: 5988, record_path: p02/p024573/p024573-2129-04-06-17-52
#
# index of last record processed successfully: 5988
# --------------------------------------
# processing record #: 5989, record_path: p02/p024573/p024573-2130-04-03-12-50
#
# index of last record processed successfully: 5989
# --------------------------------------
# processing record #: 5990, record_path: p02/p024573/p024573-2130-04-03-17-15
#
# index of last record processed successfully: 5990
# --------------------------------------
# processing record #: 5991, record_path: p02/p024573/p024573-2130-04-04-08-25
#
# index of last record processed successfully: 5991
# --------------------------------------
# processing record #: 5992, record_path: p02/p024591/p024591-2122-09-14-04-34
#
# index of last record processed successfully: 5992
# --------------------------------------
# processing record #: 5993, record_path: p02/p024591/p024591-2122-09-21-23-06
#
# index of last record processed successfully: 5993
# --------------------------------------
# processing record #: 5994, record_path: p02/p024597/p024597-2178-03-17-16-10
#
# index of last record processed successfully: 5994
# --------------------------------------
# processing record #: 5995, record_path: p02/p024605/p024605-2192-11-30-06-00
#
# index of last record processed successfully: 5995
# --------------------------------------
# processing record #: 5996, record_path: p02/p024609/p024609-2130-12-20-14-34
#
# index of last record processed successfully: 5996
# --------------------------------------
# processing record #: 5997, record_path: p02/p024609/p024609-2131-01-02-10-38
#
# index of last record processed successfully: 5997
# --------------------------------------
# processing record #: 5998, record_path: p02/p024622/p024622-2170-10-19-22-56
#
# index of last record processed successfully: 5998
# --------------------------------------
# processing record #: 5999, record_path: p02/p024626/p024626-2158-05-02-19-54
#
# index of last record processed successfully: 5999
# --------------------------------------

# %%
gigi = 2

# %%
gigi +=1

# %%
gigi
